# %%
import sys
sys.path.insert(0, "/home/wei/data/code/Wei/logisds/")

from logisds.train import Trainer
import numpy as np

# %%
trainer = Trainer(batch_size=100,
                 N_steps=300,
                 lr=0.001,
                 random_seed=1,
                 val_ratio=0.4,
                 early_stopping_round=10,
                 model_weights_path=None)
# Out:
# 2021-08-04 18:22:03,508 - INFO - Data-Processor- prepare_data -164- start normalizing data
# 2021-08-04 18:22:03,516 - INFO - Data-Processor- prepare_data -166- Normalizing completes

# %%
model = trainer.train()
# Out:
# /home/wei/anaconda3/envs/grubhub/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 202/202 [==============================] - 18s 82ms/step - loss: 1.0740 - val_loss: 1.1800
# Epoch 2/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.9414 - val_loss: 0.9220
# Epoch 3/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.9724 - val_loss: 1.1174
# Epoch 4/100
# 202/202 [==============================] - 16s 81ms/step - loss: 0.9223 - val_loss: 1.0146
# Epoch 5/100
# 202/202 [==============================] - 16s 80ms/step - loss: 0.9137 - val_loss: 0.8232
# Epoch 6/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.9008 - val_loss: 1.1099
# Epoch 7/100
# 202/202 [==============================] - 16s 80ms/step - loss: 0.8772 - val_loss: 1.0626
# Epoch 8/100
# 202/202 [==============================] - 16s 80ms/step - loss: 0.9038 - val_loss: 0.9712
# Epoch 9/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.9481 - val_loss: 1.1257
# Epoch 10/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.9140 - val_loss: 0.9298
# Epoch 11/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.9120 - val_loss: 1.1273
# Epoch 12/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.8912 - val_loss: 0.8670
# Epoch 13/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.9252 - val_loss: 1.0802
# Epoch 14/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.8662 - val_loss: 0.9354
# Epoch 15/100
# 202/202 [==============================] - 16s 79ms/step - loss: 0.8721 - val_loss: 1.0064
# 2021-08-04 18:26:13,020 - INFO - Train-RNN- train -67- Model weights have been saved to: /home/wei/data/code/Wei/logisds/logisds/../data/model

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30, 34)]     0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   [(None, 30, 32), (No 6528        input_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 960)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 960)          0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            961         dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1922        dropout[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3)            0           dense[0][0]
#                                                                  dense_1[0][0]
# ==================================================================================================
# Total params: 9,411
# Trainable params: 9,411
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=True, show_dtype=False,
    show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96
)
