# %%
import sys
sys.path.insert(0, "/home/wei/data/code/Wei/logisds/")

from logisds.train import Trainer
import numpy as np

# %%
trainer = Trainer(batch_size=100,
                 N_steps=300,
                 lr=0.001,
                 random_seed=1,
                 val_ratio=0.4,
                 early_stopping_round=10,
                 model_weights_path=None)
# Out:
# 2021-08-05 02:41:16,141 - INFO - Data-Processor- prepare_data -169- start normalizing data
# 2021-08-05 02:41:16,159 - INFO - Data-Processor- prepare_data -171- Normalizing completes

# %%
model = trainer.train()
# Out:
# /home/wei/anaconda3/envs/grubhub/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 202/202 [==============================] - 38s 172ms/step - loss: 1.0733 - val_loss: 1.1820
# Epoch 2/100
# 202/202 [==============================] - 35s 174ms/step - loss: 0.9435 - val_loss: 0.9221
# Epoch 3/100
# 202/202 [==============================] - 33s 164ms/step - loss: 0.9718 - val_loss: 1.1163
# Epoch 4/100
# 202/202 [==============================] - 32s 158ms/step - loss: 0.9218 - val_loss: 1.0130
# Epoch 5/100
# 202/202 [==============================] - 35s 174ms/step - loss: 0.9114 - val_loss: 0.8210
# Epoch 6/100
# 202/202 [==============================] - 37s 184ms/step - loss: 0.9024 - val_loss: 1.1113
# Epoch 7/100
# 202/202 [==============================] - 36s 178ms/step - loss: 0.8773 - val_loss: 1.0682
# Epoch 8/100
# 202/202 [==============================] - 31s 152ms/step - loss: 0.9007 - val_loss: 0.9687
# Epoch 9/100
# 202/202 [==============================] - 35s 172ms/step - loss: 0.9469 - val_loss: 1.1263
# Epoch 10/100
# 202/202 [==============================] - 33s 163ms/step - loss: 0.9090 - val_loss: 0.9287
# Epoch 11/100
# 202/202 [==============================] - 34s 171ms/step - loss: 0.9092 - val_loss: 1.1267
# Epoch 12/100
# 202/202 [==============================] - 34s 169ms/step - loss: 0.8875 - val_loss: 0.8614
# Epoch 13/100
# 202/202 [==============================] - 36s 180ms/step - loss: 0.9249 - val_loss: 1.0802
# Epoch 14/100
# 202/202 [==============================] - 36s 177ms/step - loss: 0.8661 - val_loss: 0.9358
# Epoch 15/100
# 202/202 [==============================] - 32s 156ms/step - loss: 0.8739 - val_loss: 1.0096
# 2021-08-05 02:50:02,267 - INFO - Train-RNN- train -87- Model weights have been saved to: /home/wei/data/code/Wei/logisds/logisds/../data/model

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 34)]    0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   [(None, 300, 32), (N 6528        input_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9600)         0           bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 9600)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            9601        dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            19202       dropout[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3)            0           dense[0][0]
#                                                                  dense_1[0][0]
# ==================================================================================================
# Total params: 35,331
# Trainable params: 35,331
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=True, show_dtype=False,
    show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96
)
