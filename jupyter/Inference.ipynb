# %%
import sys
sys.path.insert(0, "/home/wei/data/code/Wei/logisds/")

from logisds.inference import Inference

# %%
infr = Inference(N_steps=300,model_weights_path=None)
# Out:
# 2021-08-05 00:25:40,003 - INFO - Inference- __init__ -28- Loading model complete.
# 2021-08-05 00:25:40,081 - INFO - Data-Processor- prepare_data -165- start normalizing data
# 2021-08-05 00:25:40,101 - INFO - Data-Processor- prepare_data -167- Normalizing completes

# %%
# generate inference.csv
# result_inference = infr.inference()
# generate inference_halfhour.csv
result_half_hour = infr.generate_halfhour_result()
# Out:
# 2021-08-05 00:26:01,731 - INFO - Inference- generate_halfhour_result -121- {'time_beginning': '2017-06-30 00:00:00', 'number_of_event': 1}
# 2021-08-05 00:26:01,741 - INFO - Inference- generate_halfhour_result -121- {'time_beginning': '2017-06-30 00:30:00', 'number_of_event': 1}
# 2021-08-05 00:26:01,750 - INFO - Inference- generate_halfhour_result -121- {'time_beginning': '2017-06-30 01:00:00', 'number_of_event': 0}
# 2021-08-05 00:26:01,761 - INFO - Inference- generate_halfhour_result -121- {'time_beginning': '2017-06-30 01:30:00', 'number_of_event': 2}
# 2021-08-05 00:26:01,769 - INFO - Inference- generate_halfhour_result -121- {'time_beginning': '2017-06-30 02:00:00', 'number_of_event': 1}
# 2021-08-05 00:26:01,782 - INFO - Inference- generate_halfhour_result -121- {'time_beginning': '2017-06-30 02:30:00', 'number_of_event': 1}
# 2021-08-05 00:26:01,794 - INFO - Inference- generate_halfhour_result -121- {'time_beginning': '2017-06-30 03:00:00', 'number_of_event': 1}
# ...
